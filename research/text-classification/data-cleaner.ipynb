# %%
import csv
import pandas as pd
import codecs
import os
import glob

# %%
# Making a list directory
files = glob.glob('./datasets/water_tweets/gathered_water/*.csv')
#print(files)
water1_tweets = pd.read_csv('./datasets/water_tweets/water1.csv', encoding = 'ISO-8859-1', delimiter = ',')
un_h2o_tweets_1 = pd.concat([pd.read_csv(f, encoding = 'ISO-8859-1', delimiter = ';') for f in files])
un_h2o_tweets_1 = pd.concat([water1_tweets, un_h2o_tweets_1])
un_h2o_tweets_1 = un_h2o_tweets_1[['category', 'date', 'text', 'retweet_count', 'tweet_id']]
un_h2o_tweets_1 = un_h2o_tweets_1[un_h2o_tweets_1['text'] != 'text']
un_h2o_tweets_1 = un_h2o_tweets_1[un_h2o_tweets_1['category'] != 'pcb']
un_h2o_tweets_1 = un_h2o_tweets_1[un_h2o_tweets_1['category'] != 'benzene']
un_h2o_tweets_1 = un_h2o_tweets_1.drop_duplicates(subset = ['text'], keep = 'first').reset_index()
un_h2o_tweets_1 = un_h2o_tweets_1.iloc[:, 1:]
un_h2o_tweets_1.columns = ['category', 'date', 'tweet', 'retweet_count', 'tweet_id']
print(len(un_h2o_tweets_1))

un_h2o_tweets_1.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 63239
#       category             date  \
# 0  flash flood  6/25/2019 20:45
# 1  flash flood  6/25/2019 20:28
# 2  flash flood  6/25/2019 20:21
# 3  flash flood  6/25/2019 20:07
# 4  flash flood  6/25/2019 19:55
#
#                                                tweet  retweet_count  \
# ...

# %%
print(un_h2o_tweets_1.tweet[0])
# Out:
# @LeslieWalden6 @MookieTheBrave @AngusMcPussPuss @AngelaStillwell @cat_samson @arkantart @Biscuit_Meow @duchess_meow @TobiasandJasper @goodman_carina It's cwazy!! Mom tiwed of seeing flash flood warnings fwom The Weather Channel pop up on her phone evewyday. She appweciates the warning, but she knows which aweas are pwone to flooding.ð¼ð¼

# %%
un_h2o_tweets_1.to_csv(r'datasets\water_tweets\unique_water.csv', sep = ';')

# %%
print(len(un_h2o_tweets_1))
# Out:
# 63239

# %% [markdown]
# ## Checking amounts by category

# %%
by_key = un_h2o_tweets_1.groupby('category').count().reset_index()
by_key.iloc[:, 0:2]
# Out:
#                         category  date
# 0                    #algaebloom    31
# 1                 #chemicalspill     1
# 2    #drinkingwatercontamination     2
# 3                       #drought   853
# 4                         #ecoli   181
# 5                    #flashflood   522
# 6      #groundwatercontamination     6
# 7           #industrialpollution     3
# 8                      #oilspill   129
# 9                      #pipeleak     1
# 10                   #wastewater   700
# 11           #waterandsanitation     8
# 12           #watercontamination    18
# 13              #watermanagement   370
# 14               #waterpollution   221
# 15                   algae bloom  1314
# 16                chemical spill   646
# 17                coal ash water   200
# 18                drinking water  4852
# 19  drinking water contamination   118
# 20                       drought  9403
# 21                      dry well  6351
# 22                        e-coli   743
# ...

# %%
find = list(un_h2o_tweets_1[un_h2o_tweets_1['category'] == 'waste spill'].tweet)

# %%
print(find)
# Out:
# ['*@JerrieDerose On July 16, 1979, an earthen dam that held liquid uranium waste broke, releasing 1,000 tons of solid radioactive mill waste and more than 90 million gallons of acidic and radioactive liquids into the Rio Puerco. https://t.co/uLUBYo9PAT', '*@mwelchnoeyy *@kyrstensinema On July 16, 1979, an earthen dam that held liquid uranium waste broke, releasing 1,000 tons of solid radioactive mill waste and more than 90 million gallons of acidic and radioactive liquids into the Rio Puerco. https://t.co/uLUBYo9PAT', 'On July 16, 1979, an earthen dam that held liquid uranium waste broke, releasing 1,000 tons of solid radioactive mill waste and more than 90 million gallons of acidic and radioactive liquids into the Rio Puerco. https://t.co/uLUBYo9PAT', 'ð\x9f\x93¢ For the past month, *@Chevron has kept very quiet about a 4 week long oilspill in Kern!? How can you spill 13,000 barrels of oilfield waste and keep local regulators ð\x9f¤« about it?? Has the community been made aware?? Th
# ...

# %%
print(list(by_key.category))
# Out:
# ['#algaebloom', '#chemicalspill', '#drinkingwatercontamination', '#drought', '#ecoli', '#flashflood', '#groundwatercontamination', '#industrialpollution', '#oilspill', '#pipeleak', '#wastewater', '#waterandsanitation', '#watercontamination', '#watermanagement', '#waterpollution', 'algae bloom', 'chemical spill', 'coal ash water', 'drinking water', 'drinking water contamination', 'drought', 'dry well', 'e-coli', 'ecoli', 'flash flood', 'groundwater contamination', 'groundwater pollution', 'industrial pollution', 'industrial solvents', 'lake contamination', 'lake pollution', 'lead water', 'marine plastic pollution', 'metal hydroxide', 'oil spill', 'pipe leak', 'river contamination', 'stream contamination', 'toxic waste water', 'untreated waste', 'waste spill', 'waste water', 'water and sanitation', 'water contamination', 'water impurity', 'water management', 'water plastic', 'water pollution', 'water sewage', 'waterbourne disease']
