# %% [markdown]
# ## Embedding
# We start by developing an embedding of a dictionary. Since all potential words and misspellings that are in tweets would create an extremely large, but sparse vector, this would not be an efficient way of storing data.
#
# The most common solution is to represent each word in the vocabulary using a fairly small and dense vector called an *embedding*, and just let the neural network learn a good embedding for each word during training. At the beginning of training, embeddings are simply chosen randomly, but during training, backpropagation automatically moves the embeddings around in a way that helps the neural network perform its task. This means that similar words will gradually cluster close to one another, and even end up organized in a rather meaningful way. Embeddings may end up placed along various axes that represent gender, singular/plural, adjective/noun, etc.
#
# We first need to create the variable representing the embedding, then if we feed a sentence to the neural network, we first preprocess the sentence and break it into a list of known words. We may remove unnecessary characters, replace unknown words by a predefined token word such as "[UNK]", replace numerical values by "[NUM]", replace URLs with "[URL]", and so on. Once we have a list of known words, we can look up each word's integer identifier in a dictionary. At that point we are ready to feed these word identifiers to TensorFlow using a placeholder, and apply the `embedding_lookup()` function to get the corresponding embeddings.
#
# Once our model has learned good word embeddings, they can actually be reused fairly efficiently in any NLP application. In fact, instead of training our own word embeddings, we may want to download pretrained word embeddings (like using pretrained layers, we can choose to freeze the pretrained embeddings by creating an `embeddings` variable using `trainable = False`, or let backpropagation tweak them for our application. The first option will speed up training, but the second may lead to slightly higher performance.
#
# We form the dictionary from tweets scraped by keyword (list of 50 terms in `data-cleaner.ipynb`), and data collected from `twitter_samples` of the Natural Language Toolkit (`nltk`) database.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import nltk
import glob
import string
import matplotlib.pyplot as plt
import matplotlib as mpl

nltk.download('punkt')

#import errno
#import os
#import zipfile

def reset_graph(seed = 42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)
# Out:
# [nltk_data] Downloading package punkt to /home/jayaram/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# NLTK tweets
nltk.download('twitter_samples')
from nltk.corpus import twitter_samples
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jayaram/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!

# %%
twitter_samples.strings()[:5]
# Out:
# ['hopeless for tmr :(',
#  "Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(",
#  '@Hegelbon That heart sliding into the waste basket. :(',
#  '“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too',
#  'Dang starting next week I have "work" :(']

# %%
tweets = twitter_samples.tokenized()
tweet_dict = []
for i in range(len(tweets)):
    for j in range(len(tweets[i])):
        tweet_dict.append(tweets[i][j])


print(tweet_dict[:15])
# Out:
# ['hopeless', 'for', 'tmr', ':(', 'Everything', 'in', 'the', 'kids', 'section', 'of', 'IKEA', 'is', 'so', 'cute', '.']

# %% [markdown]
# ## JAYARAM: Polarity Measure
#
# The way I see the usage of this, is that we can _potentially_ use this as another input variable for our neural network. We first will have to look at the measure of polarity and its relationship to tweets' "water issue relevance". If we find that there is a strong correlation between relevance and polarity and we can justify that relationship, then we should probably use that as an input. If you can input this into our Pandas DataFrame `all_csvs` (first 5 rows seen below) as a column, `polarity`, that would be excellent.

# %%
# Making a list directory of all the tweets we have collected
files_0 = glob.glob('./datasets/water_tweets/gathered_water/*.csv')
water1_tweets = pd.read_csv('./datasets/water_tweets/water1.csv', encoding = 'ISO-8859-1', delimiter = ',')

# loading JSON files
from pandas.io.json import json_normalize
with open('datasets/water_tweets/gathered_water/water8.json', 'r', encoding="utf-8") as json_file:
    water_json_1 = pd.read_json('datasets/water_tweets/gathered_water/water8.json', typ='object', orient='columns')
    water_json_1 = pd.io.json.json_normalize(water_json_1)
    water_json_1 = water_json_1[['text', 'timestamp']]

with open('datasets/water_tweets/gathered_water/water9_drought.json', 'r', encoding = 'utf-8') as json_file:
    water_json_2 = pd.read_json('datasets/water_tweets/gathered_water/water9_drought.json', typ='object', orient='columns')
    water_json_2 = pd.io.json.json_normalize(water_json_2)
    water_json_2 = water_json_2[['text', 'timestamp']]


water_jsons = pd.concat([water_json_1, water_json_2])
water_jsons.columns = ['text', 'date']
water_jsons['retweet_count'] = np.nan
water_jsons['category'] = np.nan
water_jsons['tweet_id'] = np.nan
water_jsons = water_jsons[['category', 'date', 'text', 'retweet_count', 'tweet_id']]

# Loading uniformly formatted pulled tweets
water_csvs = pd.concat([pd.read_csv(f, encoding = 'ISO-8859-1', delimiter = ';') for f in files_0])
water_csvs = pd.concat([water1_tweets, water_csvs, water_jsons])
water_csvs = water_csvs[['category', 'date', 'text', 'retweet_count', 'tweet_id']]
water_csvs = water_csvs[water_csvs['text'] != 'text']
water_csvs = water_csvs[water_csvs['category'] != 'pcb']
water_csvs = water_csvs[water_csvs['category'] != 'benzene']
files_1 = glob.glob('./datasets/water_tweets/rnd_tweets/*.csv')
rnd_csvs = pd.concat([pd.read_csv(f, encoding = 'ISO-8859-1', delimiter = ';') for f in files_1])
rnd_csvs = rnd_csvs[['category', 'date', 'text', 'retweet_count', 'tweet_id']]
rnd_csvs = rnd_csvs[rnd_csvs['text'] != 'text']
all_csvs = pd.concat([water_csvs, rnd_csvs])
all_csvs['text'] =  all_csvs['text'].astype(str)
all_csvs = all_csvs.drop_duplicates(subset = ['text'], keep = 'first').reset_index()
all_csvs = all_csvs.iloc[:, 1:]
#all_csvs.columns = ['category', 'date', 'tweet', 'retweet_count', 'tweet_id']
print(len(all_csvs))


all_csvs.head()
# Out:
# /home/jayaram/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# /home/jayaram/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# 357107
#       category             date  \
# 0  flash flood  6/25/2019 20:45
# 1  flash flood  6/25/2019 20:28
# 2  flash flood  6/25/2019 20:21
# 3  flash flood  6/25/2019 20:07
# 4  flash flood  6/25/2019 19:55
#
#                                                 text  retweet_count  \
# 0  @LeslieWalden6 @MookieTheBrave @AngusMcPussPus...            0.0
# 1  4 PASSES to FLASH FLOOD WATER PARK in Battle C...            0.0
# 2  So the maintenance men at my apartment complex...            0.0
# 3  .@NWStulsa issued 1,530 flood/flash flood prod...            0.0
# 4  They might not call it a #climatedebate, but c...            0.0
#
#        tweet_id
# 0  1.140000e+18
# 1  1.140000e+18
# 2  1.140000e+18
# 3  1.140000e+18
# 4  1.140000e+18

# %%
#adding polarity and subjectivity
from textblob import TextBlob
#subjectivity("very bad")
# %timeit all_csvs['polarity'] = all_csvs.apply(lambda x: TextBlob(x['text']).sentiment[0], axis=1)
# %timeit all_csvs['subjectivity'] = all_csvs.apply(lambda x: TextBlob(x['text']).sentiment[1], axis=1)

print(all_csvs)
# Out:
# 4min 18s ± 2.33 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 4min 18s ± 7.93 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
#            category             date  \
# 0       flash flood  6/25/2019 20:45
# 1       flash flood  6/25/2019 20:28
# 2       flash flood  6/25/2019 20:21
# 3       flash flood  6/25/2019 20:07
# 4       flash flood  6/25/2019 19:55
# 5       flash flood  6/25/2019 19:50
# 6       flash flood  6/25/2019 19:45
# 7       flash flood  6/25/2019 19:29
# 8       flash flood  6/25/2019 19:15
# 9       flash flood  6/25/2019 19:01
# 10      flash flood  6/25/2019 18:56
# 11      flash flood  6/25/2019 18:51
# 12      flash flood  6/25/2019 18:51
# 13      flash flood  6/25/2019 18:46
# 14      flash flood  6/25/2019 18:45
# 15      flash flood  6/25/2019 18:38
# 16      flash flood  6/25/2019 18:30
# 17      flash flood  6/25/2019 18:29
# 18      flash flood  6/25/2019 18:26
# 19      flash flood  6/25/2019 18:00
# 20      flash flood  6/25/2019 18:00
# 21      flash flood  6/25/2019 17:35
# 22      flash flood  6/25/2019 17:28
# 23      flash flood  6/25/2019 17:20
# 24      flash flood  6/25/2019 17:09
# 25      flash flood  6/25/2019 16:57
# 26      flash flood  6/25/2019 16:54
# 27      flash flood  6/25/2019 16:50
# 28      flash flood  6/25/2019 16:48
# 29      flash flood  6/25/2019 16:42
# ...             ...              ...
# 357077           it  7/29/2019 23:10
# 357078           it  7/29/2019 23:10
# 357079           it  7/29/2019 23:10
# 357080           it  7/29/2019 23:10
# 357081           it  7/29/2019 23:10
# 357082           it  7/29/2019 23:10
# 357083           it  7/29/2019 23:10
# 357084           it  7/29/2019 23:10
# 357085           it  7/29/2019 23:10
# 357086           it  7/29/2019 23:10
# 357087           it  7/29/2019 23:10
# 357088           it  7/29/2019 23:10
# 357089           it  7/29/2019 23:10
# 357090           it  7/29/2019 23:10
# 357091           it  7/29/2019 23:10
# 357092           it  7/29/2019 23:10
# 357093           it  7/29/2019 23:10
# 357094           it  7/29/2019 23:10
# 357095           it  7/29/2019 23:10
# 357096           it  7/29/2019 23:10
# 357097           it  7/29/2019 23:10
# 357098           it  7/29/2019 23:10
# 357099           it  7/29/2019 23:10
# 357100           it  7/29/2019 23:10
# 357101           it  7/29/2019 23:10
# 357102           it  7/29/2019 23:10
# 357103           it  7/29/2019 23:10
# 357104           it  7/29/2019 23:10
# 357105           it  7/29/2019 23:10
# 357106           it  7/29/2019 23:10
#
#                                                      text  retweet_count  \
# 0       @LeslieWalden6 @MookieTheBrave @AngusMcPussPus...            0.0
# 1       4 PASSES to FLASH FLOOD WATER PARK in Battle C...            0.0
# 2       So the maintenance men at my apartment complex...            0.0
# 3       .@NWStulsa issued 1,530 flood/flash flood prod...            0.0
# 4       They might not call it a #climatedebate, but c...            0.0
# 5       *Flash Flood Warnings*\n*Extreme weather advis...            1.0
# 6       More info: https://t.co/HtkH9Or0b3 https://t.c...            0.0
# 7       Very Dangerous Flash Flood | Natural Disaster ...            0.0
# 8       @Rnikz_ @JoahanYT he dead ass said #DareToAchi...            0.0
# 9       The 20 Democrats will meet this week in a Miam...            1.0
# 10      Our #SummerSavingsGiveaway continues! Starting...            0.0
# 11      Please keep us in your prayers as we will be r...            0.0
# 12      Flash flood warning issued for Hawaii as freak...            0.0
# 13      Get ready for thunderstorms and flash floods t...            0.0
# 14      Beginning of this video shows Downtown Honolul...            0.0
# 15      Good morning. Flash flood warnings today ð ...            0.0
# 16      There was a flash flood on South Padre Island ...            0.0
# 17      Get ready for thunderstorms and flash floods t...            0.0
# 18      Flash flood warning issued for Hawaii as freak...            0.0
# 19      At 12:00 AM CDT, WNW Raymondville [Willacy Co,...            0.0
# 20      Flash Flood Advisory for O'ahu has been extend...            3.0
# 21      @aramoons Okay same lmao but even with this ra...            0.0
# 22      Students today are facing many crises: But of ...            0.0
# 23      Rain Bomb in Deep South Texas! - rainfall tota...            4.0
# 24      Flash flood warning issued for Hawaii as freak...            0.0
# 25      At 3:00 AM CDT, 5 SW Edinburg [Hidalgo Co, TX]...            0.0
# 26      Flash Flood Advisory on Oahu. Ponding occurrin...            0.0
# 27      The enhanced risk is still in place but has sh...            2.0
# 28      The enhanced risk is still in place but has sh...            3.0
# 29      @6_tweetunder @ramincol @toyotafield @SanAnton...            0.0
# ...                                                   ...            ...
# 357077  Fun read and interesting but I donât buy it ...            0.0
# 357078  You know what CoD and #ModernWarfare needs in ...            0.0
# 357079                                    Ozzie beats it!            0.0
# 357080  Here is the recent Average Price per Square Fo...            0.0
# 357081  Green just like my money that I take ð¦¶ð¾ð...            2.0
# 357082  *@lilysmybabypup1 *@MattDoran91 If we ever hav...            0.0
# 357083                        *@KlMTAEHEART is it raining            0.0
# 357084  *@stannskz *@skzenglishline Mdrrr tfacon t'ira...            0.0
# 357085  *@koomore2 Itâs not, I just googled the side...            0.0
# 357086  *@SlavaAvtomat *@shannonrwatts *@NRA Not true....            0.0
# 357087  Just finished my review of The Boys. Tomorrow ...            0.0
# 357088  *@MLW *@KevinVonErich *@RAMVonErich watching i...            0.0
# 357089  Omgð It feels good to know Iâm not the on...            0.0
# 357090  Former Jag Paul McGrillen..... a touching and ...            0.0
# 357091  renjun-å°èæ\n-i like it\n-can be applied ...            0.0
# 357092  I didn't play a great deal of sport in primary...            0.0
# 357093  Donât start a vibe wit me if you canât or ...            0.0
# 357094  Some of yâall have never been told âvan ha...            0.0
# 357095  nothing annoys me more than when someone expec...            0.0
# 357096  Selling this guy would be the highlight of the...            0.0
# 357097  *@MichelleRindels *@GovSisolak It's disappoint...            0.0
# 357098                 *@lr2nd2002 you need to cut it out            0.0
# 357099  *@5Solae *@JCKNIGHT2 10% of  the total holding...            0.0
# 357100                 August 10th itâs up ðð±ð¥            0.0
# 357101  *@aaqua411 *@AndreaTonti Watch the new season ...            0.0
# 357102  Les Archives dÃ©partementales du Loiret vous i...            0.0
# 357103  *@callummarkie you gotta save this tweet for w...            0.0
# 357104  i wanna watch the vlive wembley livestream all...            0.0
# 357105  *@RunTMc59006473 thanks!  If I didn't do it an...            0.0
# 357106  *@brianklaas When you leave out all the white ...            0.0
#
#             tweet_id  polarity  subjectivity
# 0       1.140000e+18  0.000000      0.000000
# 1       1.140000e+18  0.000000      0.000000
# 2       1.140000e+18 -0.300000      0.400000
# 3       1.140000e+18  0.136364      0.454545
# 4       1.140000e+18  0.000000      0.000000
# 5       1.140000e+18 -0.195312      1.000000
# 6       1.140000e+18  0.500000      0.500000
# 7       1.140000e+18 -0.340000      0.700000
# 8       1.140000e+18 -0.200000      0.366667
# 9       1.140000e+18  0.033333      0.100000
# 10      1.140000e+18  0.260000      0.373333
# 11      1.140000e+18 -0.210000      0.713333
# 12      1.140000e+18 -0.200000      0.500000
# 13      1.140000e+18  0.412500      0.500000
# 14      1.140000e+18  0.000000      0.000000
# 15      1.140000e+18  0.700000      0.600000
# 16      1.140000e+18 -0.300000      0.483333
# 17      1.140000e+18  0.412500      0.500000
# 18      1.140000e+18 -0.200000      0.500000
# 19      1.140000e+18  0.016667      0.066667
# 20      1.140000e+18  0.000000      0.000000
# 21      1.140000e+18  0.142222      0.691667
# 22      1.140000e+18  0.500000      0.500000
# 23      1.140000e+18  0.000000      0.400000
# 24      1.140000e+18 -0.200000      0.500000
# 25      1.140000e+18  0.023492      0.300317
# 26      1.140000e+18  0.000000      0.000000
# 27      1.140000e+18  0.138690      0.377381
# 28      1.140000e+18  0.138690      0.377381
# 29      1.140000e+18 -0.183333      0.416667
# ...              ...       ...           ...
# 357077  1.155980e+18  0.400000      0.350000
# 357078  1.155980e+18  0.388889      0.444444
# 357079  1.155980e+18  0.000000      0.000000
# 357080  1.155980e+18 -0.117188      0.325000
# 357081  1.155980e+18 -0.200000      0.300000
# 357082  1.155980e+18  0.200000      0.460000
# 357083  1.155980e+18  0.000000      0.000000
# 357084  1.155980e+18  0.000000      0.000000
# 357085  1.155980e+18  0.362500      0.575000
# 357086  1.155980e+18  0.014583      0.395833
# 357087  1.155980e+18  0.000000      1.000000
# 357088  1.155980e+18  0.000000      1.000000
# 357089  1.155980e+18  0.125000      0.625000
# 357090  1.155980e+18  0.160000      0.700000
# 357091  1.155980e+18  1.000000      0.300000
# 357092  1.155980e+18  0.466667      0.483333
# 357093  1.155980e+18  0.000000      0.000000
# 357094  1.155980e+18  0.000000      0.000000
# 357095  1.155980e+18  0.500000      0.500000
# 357096  1.155980e+18 -0.500000      1.000000
# 357097  1.155980e+18 -0.600000      0.700000
# 357098  1.155980e+18  0.000000      0.000000
# 357099  1.155980e+18  0.100000      0.395000
# 357100  1.155980e+18  0.000000      0.000000
# 357101  1.155980e+18  0.268182      0.477273
# 357102  1.155980e+18  0.000000      0.000000
# 357103  1.155980e+18  0.000000      0.000000
# 357104  1.155980e+18  0.000000      0.000000
# 357105  1.155980e+18  0.125000      0.100000
# 357106  1.155980e+18 -0.250000      0.322917
#
# [357107 rows x 7 columns]

# %%
from pandas import HDFStore
all_csvs.to_hdf('data_store.h5',key="all_csvs")
# Out:
# /home/jayaram/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->['category', 'date', 'text']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
tweet_text = list(all_csvs.text.astype(str))
print(tweet_text[:5])
# Out:
# ["@LeslieWalden6 @MookieTheBrave @AngusMcPussPuss @AngelaStillwell @cat_samson @arkantart @Biscuit_Meow @duchess_meow @TobiasandJasper @goodman_carina It's cwazy!! Mom tiwed of seeing flash flood warnings fwom The Weather Channel pop up on her phone evewyday. She appweciates the warning, but she knows which aweas are pwone to flooding.ð\x9f\x98¼ð\x9f\x98¼", '4 PASSES to FLASH FLOOD WATER PARK in Battle Creek, MICHIGAN - 2019 season!!! $12.00 | #WaterparkTickets | https://t.co/tIumVg5T0d Grab Your Tickets https://t.co/UQNz5zZ7vC', 'So the maintenance men at my apartment complex are leaf blowing during a flash flood warning... https://t.co/YkWkVzTvSy', '.@NWStulsa issued 1,530 flood/flash flood products in May 2019 alone!  Includes new warnings/advisories + all follow up statements #okwx #arwx https://t.co/3M9GfJyuez', 'They might not call it a #climatedebate, but considering that the venue where 20 Democrats are meeting in Miami this week was once inundated during a flash flood, it kinda is. https://t.co/xlZ66jHMXr']

# %%
# Tokenizing the tweet words
for i in range(len(tweet_text)):
    tweet = tweet_text[i]
    tweet = tweet.translate(str.maketrans('','', string.punctuation))
    tweet = tweet.split()
    for j in range(len(tweet)):
        new_word = tweet[j]
        tweet_dict.append(new_word)

# %%
print(len(tweet_dict))
new_tweet_dict = []
for i in range(len(tweet_dict)):
    word = tweet_dict[i]
    word = word.translate(str.maketrans('', '', string.punctuation))
    word = word.lower()
    new_tweet_dict.append(word)
new_tweet_dict[786085:786110]
# Out:
# 9512695
# ['the',
#  'bath',
#  'all',
#  'taps',
#  'have',
#  'isolation',
#  'valves',
#  'except',
#  'the',
#  'leaky',
#  'bath',
#  '12',
#  'httpstcouc3aoh0iwe',
#  'sweatienext',
#  'he',
#  'did',
#  'come',
#  'by',
#  'today',
#  'amp',
#  'check',
#  'the',
#  'ceiling',
#  'no',
#  'nest']

# %% [markdown]
# ## Build Our Dictionary

# %%
from collections import Counter

vocabulary_size = 50000

# UNK = unknown words, HST = hashtag, EMT = emoticon, URL is self-explanatory, THDL = Twitter handle
vocabulary = [("<UNK>", None)] + [("<HST>", None)] + [("<EMT>", None)] + [("<URL>", None)] + [("<THDL>", None)] +\
            Counter(new_tweet_dict).most_common(vocabulary_size - 1)
vocabulary = np.array([word for word, _ in vocabulary])
dictionary = {word: code for code, word in enumerate(vocabulary)}
data = np.array([dictionary.get(word, 0) for word in new_tweet_dict])
print(len(vocabulary))
#print(len(data))
# Out:
# 50004

# %%
" ".join(new_tweet_dict[:9]), data[:9]
# Out:
# ('hopeless for tmr  everything in the kids section',
#  array([10609,    14, 23904,    15,   284,    12,     5,   353,  3016]))

# %%
" ".join([vocabulary[word_index] for word_index in [10609,    14, 23904,    15,   284,    12,     5,   353,  3016]])
# Out:
# 'hopeless for tmr  everything in the kids section'

# %% [markdown]
# ## Generate Batches

# %%
from collections import deque

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=[batch_size], dtype=np.int32)
    labels = np.ndarray(shape=[batch_size, 1], dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = np.random.randint(0, span)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
np.random.seed(42)

data_index = 0
batch, labels = generate_batch(8, 2, 1)

# %%
batch, [vocabulary[word] for word in batch]
# Out:
# (array([   14,    14, 23904, 23904,    15,    15,   284,   284]),
#  ['for', 'for', 'tmr', 'tmr', '', '', 'everything', 'everything'])

# %%
labels, [vocabulary[word] for word in labels[:, 0]]
# Out:
# (array([[23904],
#         [10609],
#         [   15],
#         [   14],
#         [23904],
#         [  284],
#         [   12],
#         [   15]]),
#  ['tmr', 'hopeless', '', 'for', 'tmr', 'everything', 'in', ''])

# %%
reset_graph()
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 32     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

learning_rate = 0.01

# %%
#reset_graph()

# Input data.
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

vocabulary_size = 50004
embedding_size = 128

# Look up embeddings for inputs.
init_embeds = tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0)
embeddings = tf.Variable(init_embeds)

train_inputs = tf.placeholder(tf.int32, shape=[None])
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# Construct the variables for the NCE loss
nce_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                        stddev=1.0 / np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# Compute the average NCE loss for the batch.
# tf.nce_loss automatically draws a new sample of the negative labels each
# time we evaluate the loss.
loss = tf.reduce_mean(
    tf.nn.nce_loss(nce_weights, nce_biases, train_labels, embed,
                   num_sampled, vocabulary_size))

# Construct the Adam optimizer
optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

# Compute the cosine similarity between minibatch examples and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), axis=1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# Add variable initializer.
init = tf.global_variables_initializer()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 11:33:14.720171 12024 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
num_steps = 40001

with tf.Session() as session:
    init.run()

    average_loss = 0
    for step in range(num_steps):
        print("\rIteration: {}".format(step), end="\t")
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the training op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([training_op, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = vocabulary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in range(top_k):
                    close_word = vocabulary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)

    final_embeddings = normalized_embeddings.eval()
# Out:
# Iteration: 0	Average loss at step  0 :  290.5674133300781
# Nearest to think: foodie, respond, kazakhstan, glasses, mystical, stepped, dood, painted,
# Nearest to out: mãªme, webster, msc, trabajar, realising, derecha, subsaharan, ðððððððððð,
# Nearest to am: pequeã±a, outnumber, ughhh, battling, kendra, rapport, licking, lit,
# Nearest to from: guardiannews, enforces, 2015, barbigtea, rnb, wobbly, update, pouring,
# Nearest to she: discussion, 197, tiredinor4now, quartercentury, entropypress, worldly, selling, major,
# Nearest to if: ù¢ù, draped, repercussions, unified, smearing, 945pm, earliest, kart,
# Nearest to with: galatians, munch, simonschama, leach, papã¡s, fatbergs, wtf1, 2hrs,
# Nearest to been: bron, outboards, rohinisgh, 799, mistress, grahamkirk17, accountistlisa, whew,
# Nearest to of: nurturing, moderating, noã§ã£o, add, plank, sgt, guzzling, if,
# Nearest to <UNK>: eds, cells, gw1stpotus, precious, nodealbrexit, gloria74308094, i, piping,
# Nearest to on: coolants, countrymen, pbuh, saiba, polythene, cdu, rapping, utting,
# Nearest to they: soty, kvmidd85, existence, bookstore, ivepetthatdog, pushy, petramccarron2, moonlight,
# Nearest to well: nestle, 4ever, dear, murpharoo, âworld, inckarnataka, minnetonka, merchandise,
# Nearest to me: cindyjc007, tapintoresilience, permite, dat, carrollton, jools6691, bbusa617, 996,
# Nearest to had: 💪, goblins, u, offices, circulated, httptcoq0…, jamesmc86141084, theleaver,
# Nearest to <THDL>: econbritain, mrscupcake79, bids, sporadically, orchid, wikileaks, immer, illiteracy,
# Nearest to their: doors, reaping, dealer, disparity, bills, thatbluntbytch, piper, got7official,
# Nearest to time: europarlen, epsteins, regime, fieldwork, rã¡pido, decaf, 29, floodâ,
# Nearest to in: imagined, ð¤, wholl, surat, aladdin, retweet, votesnpgetscotland, sigue,
# Nearest to so: nous, enlist, governo, bosom, unbothered, doctorate, xi, sheriffâs,
# Nearest to her: smiley, gfuelenergy, 1600, choosepurpose, deadly, itsanitarani, freshman, experiments,
# Nearest to see: laramie, rayagada, bitching, shamila, condone, csi, âwhat, guard,
# Nearest to be: fling, currently, nancygeiser11, pd3v1ne, hippie, tight, righteous, hardingmike,
# Nearest to when: realjameswoods, quarterback, climatecrisis, dela, bananas, chainlink, ase, v,
# Nearest to know: fechas, ð¤ð, gaon, bragging, 40000, selfimprovement, 75, leaveeuofficial,
# Nearest to : insinuating, å¼eby, mayhaps, durmiendo, references, porto, minimizing, maligned,
# Nearest to your: bence, ripoff, alerts, cá»§a, clinicians, day6, wells, newcastleherald,
# Nearest to us: flippin, past, yuvasena, , unica, feeds, carrots, pogba,
# Nearest to i: accomplish, correspondent, organising, slovenia, paling, watertechnology, hag, <UNK>,
# Nearest to our: sparta, indoctrinated, edlatimore, jâai, ycamrahp18, theatres, teh, cardiac,
# Nearest to is: imran, mastoilet, dami, myogiadityanath, jooheon, percebi, mydesert, larger,
# Nearest to how: shouldnât, bho, placed, ianfmusgrave, entertained, photographer, astral, layers,
# Iteration: 2000	Average loss at step  2000 :  123.53270057868957
# Iteration: 4000	Average loss at step  4000 :  54.142062168836596
# Iteration: 6000	Average loss at step  6000 :  32.122798001408576
# Iteration: 8000	Average loss at step  8000 :  22.322120554447174
# Iteration: 10000		Average loss at step  10000 :  26.692201754689215
# Nearest to think: know, <UNK>, put, but, believe, launch, oklahoma, ,
# Nearest to out: à¤¬, to, bushes, awe, unhealthy, maine, newly, ,
# Nearest to am: im, but, zone, brightest, stairs, removing, fire, willacy,
# Nearest to from: in, and, <UNK>, squashed, to, finger, with, on,
# Nearest to she: adds, personality, supervisor, appointments, iii, it, muffins, sticky,
# Nearest to if: but, , do, so, and, diaper, chips, headlining,
# Nearest to with: , and, in, for, billionaires, to, <UNK>, the,
# Nearest to been: seen, controlled, restrictive, fried, mouths, bugger, criticises, apparent,
# Nearest to of: in, the, , is, and, a, hounds, on,
# Nearest to <UNK>: , willacy, the, in, a, helenzille, declared, and,
# Nearest to on: in, , and, the, of, <UNK>, with, for,
# Nearest to they: you, i, à¥¤, we, recommend, people, it, awelab1956,
# Nearest to well: dry, scheduled, weapons, , lottery, kenedy, regional, quiz,
# Nearest to me: , you, aqui, <UNK>, twat, ready, my, discovered,
# Nearest to had: julie, with, deported, kind, want, unsuccessful, have, like,
# Nearest to <THDL>: bids, sporadically, orchid, fond, wikileaks, pricing, immer, illiteracy,
# Nearest to their: the, a, prepare, of, fried, <UNK>, , dice,
# Nearest to time: trail, know, think, <UNK>, leaflet, birth, predator, mouths,
# Nearest to in: the, and, of, is, <UNK>, for, with, to,
# Nearest to so: it, , that, a, childrenâs, too, or, à¤¸à¤¾à¤§à¥,
# Nearest to her: came, beet, tears, canadian, part, recalling, scotland, explanation,
# Nearest to see: do, spirit, à¤¬, affecting, pact, protest, fella, installation,
# Nearest to be: refuse, exposure, not, have, soak, surrey, get, find,
# Nearest to when: trail, oklahoma, trickle, empty, jakepainter2, , resignation, after,
# Nearest to know: think, do, they, luxembourg, aware, reckon, isitok, affecting,
# Nearest to : <UNK>, and, but, with, the, robert, oppose, mouths,
# Nearest to your: the, my, a, and, cartoons, becivilme, our, gifted,
# Nearest to us: the, <UNK>, à¤¬à¤¾à¤¤, didn, leaking, standuptoukip, your, him,
# Nearest to i: you, they, we, but, , <UNK>, it, this,
# Nearest to our: the, identity, your, and, 》, <UNK>, conscience, frank,
# Nearest to is: in, and, of, a, , the, <UNK>, blood,
# Nearest to how: , much, after, monitor, people, amazes, disappointing, 1030,
# Iteration: 12000	Average loss at step  12000 :  23.805626954197884
# Iteration: 14000	Average loss at step  14000 :  20.531918751239775
# Iteration: 16000	Average loss at step  16000 :  19.02932406911254
# Iteration: 18000	Average loss at step  18000 :  17.51845998120308
# Iteration: 20000	Average loss at step  20000 :  15.484115224063396
# Nearest to think: but, not, do, know, need, was, have, wraps,
# Nearest to out: water, back, drinking, and, that, drought, ð£, is,
# Nearest to am: onegallon, a, pm, are, and, just, but, puke,
# Nearest to from: and, clemente, of, on, is, for, in, à®à®¤à¯à®¤à®°à®µà¯,
# Nearest to she: that, poland, devoured, maggie, hudster4, rossmaguirenb, homies, relationships,
# Nearest to if: willacy, but, mariners, that, , patagonian, preserving, contribute,
# Nearest to with: chiefs, and, <UNK>, for, when, management, yesgiffnock, on,
# Nearest to been: has, shouldnât, had, just, 2283, pretreatment, drinking, wrapping,
# Nearest to of: the, a, , and, in, disk, is, à¤¸à¥à¤¨à¤¾,
# Nearest to <UNK>: that, water, and, the, à¤¹à¤®à¤¾à¤°à¥, , in, dry,
# Nearest to on: , <UNK>, oil, chiefs, alexxmcarthur, spill, in, fundamental,
# Nearest to they: we, you, i, not, even, , to, desalinization,
# Nearest to well: dry, , willacy, once, curb, waterprovider, just, patagonian,
# Nearest to me: the, maggie, 123, entangling, alaska, it, httpstcojbkibqfkbu, sunpolitics,
# Nearest to had: lib, okx, today, swallow, waterequipment, but, interferes, have,
# Nearest to <THDL>: fond, orchid, hayes, immer, wikileaks, classified, illiteracy, deve,
# Nearest to their: , patagonian, reworks, xs, the, interferes, swim, httpstcojbkibqfkbu,
# Nearest to time: à¤¹à¤°à¤¿à¤¯à¤¾à¤£à¤¾, duxbury, it, establishment, flash, today, but, that,
# Nearest to in: <UNK>, that, and, of, establishment, , 2283, on,
# Nearest to so: just, and, when, it, but, water, <UNK>, a,
# Nearest to her: the, shaking, its, hvac, pha, their, honour, boil,
# Nearest to see: know, explain, think, guess, get, pep, encourage, do,
# Nearest to be: and, not, have, nationalmarineweek, but, fill, in, <UNK>,
# Nearest to when: and, but, , are, so, <UNK>, was, a,
# Nearest to know: have, think, but, believe, do, <UNK>, said, see,
# Nearest to : and, mariners, patagonian, <UNK>, management, that, well, is,
# Nearest to your: my, funding, the, awe, , nonstick, ks, mrsa,
# Nearest to us: the, bores, oht, muller, tariffs, urbanization, dont, it,
# Nearest to i: you, that, it, not, now, and, drinking, we,
# Nearest to our: the, ouch, didn, pills, rhea, walmart, httpstcoreaze3mbg7, plastic,
# Nearest to is: , and, wilkes, hypocritical, but, <UNK>, clemente, willacy,
# Nearest to how: so, bathe, separately, that, <UNK>, dry, , still,
# Iteration: 22000	Average loss at step  22000 :  14.65310280150175
# Iteration: 24000	Average loss at step  24000 :  14.391224988460541
# Iteration: 26000	Average loss at step  26000 :  14.042517279803754
# Iteration: 28000	Average loss at step  28000 :  13.688684256792069
# Iteration: 30000	Average loss at step  30000 :  13.27323412424326
# Nearest to think: kodiakspal2, , cheesy, 9am, out, can, how, just,
# Nearest to out: wounded, like, choppy, to, on, 837, think, realise,
# Nearest to am: , rigged, pm, 16, httpstcojbkibqfkbu, onegallon, kodiakspal2, bfc,
# Nearest to from: to, and, in, , is, of, into, horse,
# Nearest to she: systematically, rlx, arvindkumarias, highwind, rearranging, i, genuinely, ds,
# Nearest to if: when, , rakyat, oht, greensboro, would, do, is,
# Nearest to with: <UNK>, to, after, and, marketed, that, hips, on,
# Nearest to been: michaels, warning, has, we, reworks, and, 6hrs, issued,
# Nearest to of: the, , in, for, on, <UNK>, and, beginnings,
# Nearest to <UNK>: the, a, , to, on, and, greensboro, that,
# Nearest to on: <UNK>, and, of, is, to, in, marketed, with,
# Nearest to they: we, you, oht, coachdavidlubin, nrl, reinforced, to, negate,
# Nearest to well: dry, , so, <UNK>, nwsc, it, davidbegnaud, mehdirhasan,
# Nearest to me: you, coachdavidlubin, horse, <UNK>, i, , us, reacted,
# Nearest to had: need, appease, just, culpable, willacy, shopsmartresist, londoners, nickclegg,
# Nearest to <THDL>: pricing, orchid, hayes, immer, wikileaks, deve, ohtani, 00mm,
# Nearest to their: the, our, oht, exceptional, cps, to, arson, 1100pm,
# Nearest to time: us, like, importa, listeriaâ, water, oht, <UNK>, 2283,
# Nearest to in: and, the, for, , is, from, of, to,
# Nearest to so: as, , and, not, well, too, corey, how,
# Nearest to her: the, afdb, prwx, bonecolector48, tanning, marketed, , natalieben,
# Nearest to see: interact, know, sustaining, snuggle, gn, mac123m, helena, subsidizing,
# Nearest to be: this, to, lead, deploy, 0600, you, have, being,
# Nearest to when: if, cordes, turnover, can, clarifies, à¤à¤°à¥à¤à¥¤, , treaty,
# Nearest to know: 2283, nassau, coupon, remember, owns, à¤à¤¡à¤µà¤¾à¤à¤à¤°à¥, you, do,
# Nearest to : yarok, and, to, <UNK>, mariners, the, coachdavidlubin, bestsmelling,
# Nearest to your: my, , the, our, yarok, his, gull, à¤µà¤¿à¤¨à¥à¤¦,
# Nearest to us: time, our, its, evolving, to, me, â¹1, clean,
# Nearest to i: you, that, it, to, , we, <UNK>, nationalmarineweek,
# Nearest to our: the, cheatham, and, my, us, to, your, pnpcbc,
# Nearest to is: and, in, , to, from, has, 2283, on,
# Nearest to how: mariners, that, it, , <UNK>, batonrouge, you, think,
# Iteration: 32000	Average loss at step  32000 :  12.442045709967614
# Iteration: 34000	Average loss at step  34000 :  12.08463012611866
# Iteration: 36000		Average loss at step  36000 :  12.777556474924088
# Iteration: 38000			Average loss at step  38000 :  11.682240109503269
# Iteration: 40000							Average loss at step  40000 :  12.05164220070839
# Nearest to think: have, but, need, know, sp, homophobic, nationalists, ,
# Nearest to out: 1015am, into, à¤¹à¤°à¤¿à¤¯à¤¾à¤£à¤¾, hols, crude, arkadelphia, scottishnationalism, bloat,
# Nearest to am: until, pm, coachdavidlubin, rigged, , jul, cdt, 630am,
# Nearest to from: of, in, <UNK>, to, oht, orâ¦, , get,
# Nearest to she: 2283, swas, it, we, muster, affinitywater, has, scars,
# Nearest to if: , but, when, and, are, will, not, oht,
# Nearest to with: <UNK>, in, the, to, as, and, of, on,
# Nearest to been: has, peasants, you, go, coachdavidlubin, a, have, correspondence,
# Nearest to of: and, the, in, is, <UNK>, to, on, waste,
# Nearest to <UNK>: the, and, water, for, , a, in, of,
# Nearest to on: in, of, and, <UNK>, to, , the, with,
# Nearest to they: you, we, i, it, not, to, , and,
# Nearest to well: dry, it, just, get, <UNK>, indies, they, 645am,
# Nearest to me: them, you, us, wounded, todavã­a, it, like, fouls,
# Nearest to had: think, heard, get, be, do, eddy, have, ðthe,
# Nearest to <THDL>: wick, waisted, aquã­, efficacy, registered, orchid, hayes, deve,
# Nearest to their: the, us, and, oht, moggmentum, httpstcojbkibqfkbu, you, ,
# Nearest to time: all, swas, <UNK>, brice, , because, with, and,
# Nearest to in: and, of, <UNK>, water, on, to, with, ,
# Nearest to so: when, if, that, is, too, do, and, not,
# Nearest to her: your, us, work, em, httpstcofyi6cscrzi, tacobell, rabbit, newyorker,
# Nearest to see: like, do, it, moisturise, need, dry, think, get,
# Nearest to be: have, muni, make, you, to, it, 645am, beispiel,
# Nearest to when: <UNK>, , and, because, if, so, it, oht,
# Nearest to know: do, have, think, can, personas, get, they, 2283,
# Nearest to : yarok, <UNK>, pleasants, and, httpstcofztbv5netc, hydroxide, coachdavidlubin, bestsmelling,
# Nearest to your: the, and, of, you, water, <UNK>, all, in,
# Nearest to us: to, <UNK>, the, you, all, formal, our, those,
# Nearest to i: you, <UNK>, we, it, they, and, optics, swas,
# Nearest to our: the, <UNK>, and, my, 1kg, it, theresa, water,
# Nearest to is: and, of, for, 2283, the, <UNK>, water, not,
# Nearest to how: and, it, 645am, irans, be, joey, why, water,

# %%
np.save("./my_final_embeddings_tweets.npy", final_embeddings)

# %% [markdown]
# ## Plotting the Embedding

# %%
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
        
from sklearn.manifold import TSNE

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [vocabulary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 153 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 159 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 159 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 148 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Randomly Sampling the Gathered Tweets

# %%
def rnd_sample_csv(dataframe, size, keyword_type, num):
    
    '''dataframe needs to be a pandas dataframe,
    size is the number we are randomly sampling, should be an integer,
    keyword needs to be a string,
    num is the number of the file, should be an integer'''
    
    sampled_df = dataframe.sample(n = size, replace = False, random_state = 42)
    path = "datasets/water_tweets/sampled_tweets"
    file_name = "sampled_tweets_" + str(keyword_type) + str(num) + ".csv"
    sampled_df.to_csv(str(path) + '/' + str(file_name), sep = ';')

# %%
rnd_sample_csv(water_csvs, 10000, 'water', 0)
rnd_sample_csv(all_csvs, 20000, 'all', 0)
